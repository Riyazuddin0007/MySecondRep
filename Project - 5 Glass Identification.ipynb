# %% [markdown]
# # Glass Identification Dataset
# Problem Statement:
# The dataset describes the chemical properties of glass and involves classifying samples of glass using their chemical properties as one of six classes. The dataset was credited to Vina Spiehler in 1987. The study of classification of types of glass was motivated by criminological investigation. At the scene of the crime, the glass left can be used as evidence...if it is correctly identified!
#
#
# The chemical compositions are measured as the weight percent in corresponding oxide.
#
# Attribute Information-
#
#  Id number: 1 to 214
#  RI: refractive index
# Na: Sodium (unit measurement: weight percent in corresponding oxide, as are attributes 4-10)
# Mg: Magnesium
# Al: Aluminum
# Si: Silicon
# K: Potassium
# Ca: Calcium
# Ba: Barium
# Fe: Iron
# Type of glass: (class attribute)
# 1- building_windows_float_processed
# 2- building_windows_non_float_processed
# 3- vehicle_windows_float_processed
# 4- vehicle_windows_non_float_processed (none in this database)
# 5- containers
# 6- tableware
# 7- headlamps
#
# There are 214 observations in the dataset. The dataset can be divided into window glass (classes 1-4) and non-window glass (classes 5-7).
#
#
# Predict : Type of glass

# %%
import numpy as np
import pandas as pd

# %%
#Making dataframes with columns name

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv',names=['Id number','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Type of glass'])

# %%
df.head()
# Out:
#    Id number       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0          1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1          2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2          3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3          4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4          5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#    Type of glass
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
df.tail()
# Out:
#      Id number       RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  \
# 209        210  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0
# 210        211  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0
# 211        212  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0
# 212        213  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0
# 213        214  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0
#
#      Type of glass
# 209              7
# 210              7
# 211              7
# 212              7
# 213              7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id number      214 non-null    int64
#  1   RI             214 non-null    float64
#  2   Na             214 non-null    float64
#  3   Mg             214 non-null    float64
#  4   Al             214 non-null    float64
#  5   Si             214 non-null    float64
#  6   K              214 non-null    float64
#  7   Ca             214 non-null    float64
#  8   Ba             214 non-null    float64
#  9   Fe             214 non-null    float64
#  10  Type of glass  214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
df[df==" "].sum()
# Out:
# Id number        0.0
# RI               0.0
# Na               0.0
# Mg               0.0
# Al               0.0
# Si               0.0
# K                0.0
# Ca               0.0
# Ba               0.0
# Fe               0.0
# Type of glass    0.0
# dtype: float64

# %%
df.describe()
# Out:
#         Id number          RI          Na          Mg          Al          Si  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean   107.500000    1.518365   13.407850    2.684533    1.444907   72.650935
# std     61.920648    0.003037    0.816604    1.442408    0.499270    0.774546
# min      1.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     54.250000    1.516522   12.907500    2.115000    1.190000   72.280000
# 50%    107.500000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    160.750000    1.519157   13.825000    3.600000    1.630000   73.087500
# max    214.000000    1.533930   17.380000    4.490000    3.500000   75.410000
#
#                 K          Ca          Ba          Fe  Type of glass
# count  214.000000  214.000000  214.000000  214.000000     214.000000
# mean     0.497056    8.956963    0.175047    0.057009       2.780374
# ...

# %% [markdown]
# we know that it doesn't have any null values and all the attributes are numerical. Even the type which is categorical in nature is represented as integers. Please note there is no order among the classes.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.scatter(df.index,df['RI'])

# %%
df['RI'].plot(kind ='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(df.index,df['Na'])

# %%
df['Na'].plot(kind ='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(df.index,df['Mg'])

# %%
df['Mg'].plot(kind ='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(df.index,df['Al'])

# %%
df['Al'].plot(kind ='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(df.index,df['Si'])

# %%
df['Si'].plot(kind ='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(df.index,df['K'])

# %%
df['K'].plot(kind ='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(df.index,df['Ca'])

# %%
df['Ca'].plot(kind ='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(df.index,df['Ba'])

# %%
df['Ba'].plot(kind ='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.scatter(df.index,df['Fe'])

# %%
df['Fe'].plot(kind ='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#bivariate analysis

# %%
sns.scatterplot(y=df.index, x=df['RI'], hue=df['Type of glass'],palette='deep')
# Out:
# <AxesSubplot:xlabel='RI'>

# %%
sns.scatterplot(y=df.index, x=df['Na'], hue=df['Type of glass'],palette='deep')
# Out:
# <AxesSubplot:xlabel='Na'>

# %%
sns.scatterplot(y=df.index, x=df['Mg'], hue=df['Type of glass'],palette='deep')
# Out:
# <AxesSubplot:xlabel='Mg'>

# %%
sns.scatterplot(y=df.index, x=df['Al'], hue=df['Type of glass'],palette='deep')
# Out:
# <AxesSubplot:xlabel='Al'>

# %%
sns.scatterplot(y=df.index, x=df['Si'], hue=df['Type of glass'],palette='deep')
# Out:
# <AxesSubplot:xlabel='Si'>

# %%
sns.scatterplot(y=df.index, x=df['K'], hue=df['Type of glass'],palette='deep')
# Out:
# <AxesSubplot:xlabel='K'>

# %%
sns.scatterplot(y=df.index, x=df['Ca'], hue=df['Type of glass'],palette='deep')
# Out:
# <AxesSubplot:xlabel='Ca'>

# %%
sns.scatterplot(y=df.index, x=df['Ba'], hue=df['Type of glass'],palette='deep')
# Out:
# <AxesSubplot:xlabel='Ba'>

# %%
sns.scatterplot(y=df.index, x=df['Fe'], hue=df['Type of glass'],palette='deep')
# Out:
# <AxesSubplot:xlabel='Fe'>

# %%
sns.scatterplot(x=df['Fe'],y=df['Type of glass'],palette='deep',hue=df['Type of glass'])
# Out:
# <AxesSubplot:xlabel='Fe', ylabel='Type of glass'>

# %%
df.columns
# Out:
# Index(['Id number', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe',
#        'Type of glass'],
#       dtype='object')

# %%
df.corr()
# Out:
#                Id number        RI        Na        Mg        Al        Si  \
# Id number       1.000000 -0.072209  0.375722 -0.650328  0.490113  0.061232
# RI             -0.072209  1.000000 -0.191885 -0.122274 -0.407326 -0.542052
# Na              0.375722 -0.191885  1.000000 -0.273732  0.156794 -0.069809
# Mg             -0.650328 -0.122274 -0.273732  1.000000 -0.481799 -0.165927
# Al              0.490113 -0.407326  0.156794 -0.481799  1.000000 -0.005524
# Si              0.061232 -0.542052 -0.069809 -0.165927 -0.005524  1.000000
# K               0.003149 -0.289833 -0.266087  0.005396  0.325958 -0.193331
# Ca              0.090800  0.810403 -0.275442 -0.443750 -0.259592 -0.208732
# Ba              0.451001 -0.000386  0.326603 -0.492262  0.479404 -0.102151
# Fe             -0.072794  0.143010 -0.241346  0.083060 -0.074402 -0.094201
# Type of glass   0.877357 -0.164237  0.502898 -0.744993  0.598829  0.151565
#
#                       K        Ca        Ba        Fe  Type of glass
# ...

# %%
sns.heatmap(df.corr(),annot=True,fmt='0.02f',linecolor='Pink',linewidths=.5)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#         Id number          RI          Na          Mg          Al          Si  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean   107.500000    1.518365   13.407850    2.684533    1.444907   72.650935
# std     61.920648    0.003037    0.816604    1.442408    0.499270    0.774546
# min      1.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     54.250000    1.516522   12.907500    2.115000    1.190000   72.280000
# 50%    107.500000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    160.750000    1.519157   13.825000    3.600000    1.630000   73.087500
# max    214.000000    1.533930   17.380000    4.490000    3.500000   75.410000
#
#                 K          Ca          Ba          Fe  Type of glass
# count  214.000000  214.000000  214.000000  214.000000     214.000000
# mean     0.497056    8.956963    0.175047    0.057009       2.780374
# ...

# %%
plt.figure(figsize=(9,6))
sns.heatmap(df.describe()[1:],annot=True,fmt='0.02f',linecolor='pink',linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
df['Type of glass'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %%
df['Type of glass'].value_counts()
sns.countplot(df['Type of glass'])
# Out:
# C:\Users\RIYAZ\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type of glass', ylabel='count'>

# %%
#the output data is imbalace need to balance the dataset

# %%
#Checking outliers

# %%
collist=df.columns.values
ncol=6
nrow =2
plt.figure(figsize=(ncol,1*ncol))
for i in range(0,len(collist)):
    plt.title(i)
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data=df[collist[i]],color='green',orient="v")
    plt.tight_layout()

# %%
df.skew()
# Out:
# Id number        0.000000
# RI               1.625431
# Na               0.454181
# Mg              -1.152559
# Al               0.907290
# Si              -0.730447
# K                6.551648
# Ca               2.047054
# Ba               3.416425
# Fe               1.754327
# Type of glass    1.114915
# dtype: float64

# %%
#by default range of skewness is +/- .5

# %%
#the following columns has skweness posative =(RI,Al,K),  skweness negative(Mg,Si)

# %%
plt.figure(figsize=(1,5))
sns.displot(df['RI'],kde=True)

# %%
#the data is not normalized.it show skewness

# %%
sns.displot(df["Na"],kde=True)

# %%
#the data is not normalized.it show skewness

# %%
sns.displot(df["Mg"],kde=True)

# %%
#the data is not normalized.it show skewness

# %%
sns.displot(df["Al"],kde=True)

# %%
#the data is not normalized.it show skewness

# %%
sns.displot(df["Si"],kde=True)

# %%
#the data is not normalized.it show skewness

# %%
sns.displot(df["K"],kde=True)

# %%
#the data is not normalized.it show skewness

# %%
sns.displot(df["Ca"],kde=True)

# %%
#the data is not normalized.it show skewness

# %%
sns.displot(df["Ba"],kde=True)

# %%
#the data is not normalized.it show skewness

# %%
sns.set(style="whitegrid")
sns.countplot('Type of glass',data=df).set_title('Count of Glass Types')
# Out:
# C:\Users\RIYAZ\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Count of Glass Types')

# %%
#Showing that more than 65% of data belongs to tye 1 and 2

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (20,15))
plt.subplot(3,3,1)
sns.boxplot(x='Type of glass', y='RI', data=df)
plt.subplot(3,3,2)
sns.boxplot(x='Type of glass', y='Na', data=df)
plt.subplot(3,3,3)
sns.boxplot(x='Type of glass', y='Mg', data=df)
plt.subplot(3,3,4)
sns.boxplot(x='Type of glass', y='Al', data=df)
plt.subplot(3,3,5)
sns.boxplot(x='Type of glass', y='Si', data=df)
plt.subplot(3,3,6)
sns.boxplot(x='Type of glass', y='K', data=df)
plt.subplot(3,3,7)
sns.boxplot(x='Type of glass', y='Ca', data=df)
plt.subplot(3,3,8)
sns.boxplot(x='Type of glass', y='Ba', data=df)
plt.subplot(3,3,9)
sns.boxplot(x='Type of glass', y='Fe', data=df)
plt.show()

# %% [markdown]
# Sodium content is higher in Type 6 & 7, whereas Magnesium content is fairly high in Type 1, 2 & 3. Aluminium is higher in type 5 & 7.
#
# We got some idea on which feature provides more insight in differentiating one type from another. Now, let's see the relationship between each one of them through a pairplot. (We will leave out K, Ba and Fe due to sparse concentration)

# %%
#pair plot
sns.pairplot(df[['RI','Na','Mg','Al','Si','Ca']], kind='reg')

# %% [markdown]
# we can clearly see some strong relationship between Calcium and Refractive index. Silica and RI seem to have an inverse relationship.

# %% [markdown]
# Density plot of flat vs non-flat glass on some of the properties.

# %%
sns.set(style="whitegrid", font_scale=1.3)
plt.subplots(figsize = (20,10))
plt.subplot(2,2,1)
sns.kdeplot(df["RI"][df['Type of glass'] == 1], shade = True)
sns.kdeplot(df["RI"][df['Type of glass'] == 2], shade = True)
sns.kdeplot(df["RI"][df['Type of glass'] == 3], shade = True)
plt.title("RI Distribution for flat vs. non-flat glass")
plt.legend(['Type 1', 'Type 2', 'Type 3'])
plt.subplot(2,2,2)
sns.kdeplot(df["Si"][df['Type of glass'] == 1], shade = True)
sns.kdeplot(df["Si"][df['Type of glass'] == 2], shade = True)
sns.kdeplot(df["Si"][df['Type of glass'] == 3], shade = True)
plt.title("Si Distribution for flat vs. non-flat glass")
plt.legend(['Type 1', 'Type 2', 'Type 3'])
plt.subplot(2,2,3)
sns.kdeplot(df["Mg"][df['Type of glass'] == 1], shade = True)
sns.kdeplot(df["Mg"][df['Type of glass'] == 2], shade = True)
sns.kdeplot(df["Mg"][df['Type of glass'] == 3], shade = True)
plt.title("Mg Distribution for flat vs. non-flat glass")
plt.legend(['Type 1', 'Type 2', 'Type 3'])
plt.subplot(2,2,4)
sns.kdeplot(df["Al"][df['Type of glass'] == 1], shade = True)
sns.kdeplot(df["Al"][df['Type of glass'] == 2], shade = True)
sns.kdeplot(df["Al"][df['Type of glass'] == 3], shade = True)
plt.title("Al Distribution for flat vs. non-flat glass")
plt.legend(['Type 1', 'Type 2', 'Type 3'])

# %% [markdown]
# Mostly the flat ones (1,3) overlap on all the properties except Aluminium. Aluminium has a wider range for type 3 than type 1. The non-float glass, type 2 has many extreme points which make its range very high.

# %% [markdown]
# Feature Selection using PCA

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(),cmap='YlGnBu',annot=True, linewidth=.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# In the pairplot, RI and Ca have a high positive correlation, and Si and RI, negative.
# But since this is a classification technique and not regression, we cannot simply remove the collinear variables from the model, as they might be able to explain the difference between the target labels.

# %% [markdown]
# Principal component analysis to decide on the candidate variables. This is valuable as it can help in dimension reduction.

# %%
from sklearn.decomposition import PCA

# Performing PCA
X_var =df[['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe']]
pca = PCA(random_state = 1)
pca.fit(X_var)
var_exp = pca.explained_variance_ratio_
cum_var_exp = np.cumsum(var_exp)
var_df = pd.DataFrame(pca.explained_variance_.round(2), index=["P" + str(i) for i in range(1,10)],
                      columns=["Explained_Variance"])
print(var_df.T)
plt.figure(figsize=(12,7))
plt.bar(range(1,len(cum_var_exp)+1), var_exp, align= 'center', label= 'individual variance', color='teal', alpha = 0.8)
plt.step(range(1,len(cum_var_exp)+1), cum_var_exp, where = 'mid' , label= 'cumulative variance', color='red')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.xticks(np.arange(1,len(var_exp)+1,1))
plt.legend(loc='center right')
plt.show()
# Out:
#                      P1    P2    P3    P4    P5   P6    P7   P8   P9
# Explained_Variance  3.0  1.66  0.68  0.64  0.21  0.1  0.01  0.0  0.0

# %% [markdown]
# The first 5 components account for about 99% of the total explained variance. We can run the analysis again only with these five components.

# %%
pca_red = PCA(n_components=5)
X_reduced = pca_red.fit_transform(X_var)

# %% [markdown]
# Now that we have our features and target labels,

# %% [markdown]
# Model Development

# %%
# Separating the response (y) and explanatory (x) variables
X = X_reduced
y = df["Type of glass"].values

# %%
# from sklearn.cross_validation import train_test_split

# from sklearn.cross_validation import train_test_split

from sklearn.model_selection import train_test_split

# Splitting the dataset into test and training with 70% for training the model
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3, random_state=25)

# Check whether the train and test have instances of all the glass types
print(np.unique(y_train))
print(np.unique(y_test))
# Out:
# [1 2 3 5 6 7]
# [1 2 3 5 6 7]

# %%
# !pip install xgboost

# %%
# For data science and machine learning techniques
from sklearn.decomposition import PCA

from sklearn import metrics
from sklearn import tree
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
# Support Vector Machines
svmMod = SVC()
svmMod.fit(X_train,y_train)
y_pred = svmMod.predict(X_test)
sc1 = metrics.accuracy_score(y_pred,y_test)

# %%
# Random Forest
RandFor = RandomForestClassifier(max_depth = 3, min_samples_split=2, n_estimators = 50, random_state = 1)
RandFor.fit(X_train, y_train)
y_pred = RandFor.predict(X_test)
sc2 = metrics.accuracy_score(y_pred,y_test)

# %%
# Gradient Boost Classifier
gbmMod = GradientBoostingClassifier(max_depth = 3, n_estimators = 100, learning_rate = 0.05, random_state = 1)
gbmMod.fit(X_train,y_train)
y_pred = gbmMod.predict(X_test)
sc3 = metrics.accuracy_score(y_pred,y_test)

# %%
# Decision Tree
DecTree = tree.DecisionTreeClassifier()
DecTree.fit(X_train, y_train)
y_pred = DecTree.predict(X_test)
sc4 = metrics.accuracy_score(y_pred,y_test)

# %%
print(DecTree.feature_importances_)
print(RandFor.feature_importances_)
print(gbmMod.feature_importances_)
# Out:
# [0.20551708 0.35157808 0.16880923 0.21888695 0.05520865]
# [0.31377335 0.32296928 0.05489302 0.21178263 0.09658172]
# [0.3352693  0.28759977 0.13390681 0.17182611 0.07139801]

# %%
# Compare accuracy of models
pd.DataFrame([['Support Vector Machine',sc1],['Random Forest',sc2],['Gradient Boost',sc3],
                             ['Decision Tree',sc4],],
                                 columns=['Model','Accuracy'])
# Out:
#                     Model  Accuracy
# 0  Support Vector Machine  0.753846
# 1           Random Forest  0.738462
# 2          Gradient Boost  0.676923
# 3           Decision Tree  0.630769

# %% [markdown]
# SVM gives the highest accuracy and all the features seem to be important from the other models. So, we will retain SVM as our final model and perform hyperparameter tuning to improve it.
#
# Hyperparameter tuning

# %%
tuned_para = [{'kernel': ['rbf','linear'], 'gamma': [0.001, 0.01, 0.1, 10],
                     'C': [0.001, 0.01, 0.1, 1, 10]}]
grid = GridSearchCV(SVC(), tuned_para, cv=5, scoring='accuracy')
grid.fit(X_train, y_train)
print("Best parameters set found on development set:")
print()
print(grid.best_params_)
# Out:
# Best parameters set found on development set:
#
# {'C': 10, 'gamma': 10, 'kernel': 'rbf'}

# %%
# Running final model
model = grid.best_estimator_
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
metrics.accuracy_score(y_pred,y_test)
# Out:
# 0.6923076923076923

# %%
# Let's plot the confusion matrix
mat = confusion_matrix(y_test, y_pred)
plt.subplots(figsize=(12,8))
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# Text(197.86, 0.5, 'predicted label')

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.80      0.70      0.74        23
#            2       0.66      0.84      0.74        25
#            3       0.17      0.50      0.25         2
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         3
#            7       1.00      0.70      0.82        10
#
#     accuracy                           0.69        65
#    macro avg       0.44      0.46      0.43        65
# weighted avg       0.69      0.69      0.68        65
# C:\Users\RIYAZ\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# Training the model with the entire data (Since cross-validation is already done)
svm_mod = SVC(C=10, gamma=0.1, kernel='rbf')
svm_mod.fit(X_var.iloc[:,0:5],y)
# Out:
# SVC(C=10, gamma=0.1)

# %% [markdown]
# Saving the best model

# %%
import joblib
joblib.dump(model,'GlassIdentificationModel.pkl')
# Out:
# ['GlassIdentificationModel.pkl']
